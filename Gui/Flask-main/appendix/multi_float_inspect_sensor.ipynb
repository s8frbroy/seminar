# %%
import util as util

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
multi_float = util.load_multi_data(3,10, "float")
multi_int = util.load_multi_data(52,99, "int")

# %%
multi_float['sensor_id'].value_counts()
# Out:
# 6633    585905
# 6632    584362
# 6636    575204
# 6634    573780
# 6635    573016
# 6223    276385
# 6222    195902
# 6896    135453
# Name: sensor_id, dtype: int64

# %% [markdown]
# ### inspect 6632 (coffeemaker)

# %%
df = util.line_plot_multi(multi_float, 6632, "coffemaker", 490000, [0,2000])

# %%
util.hist_plot_multi(multi_float, 6632, "cooffeemaker", [0,120])
# Out:
#         value_id  sensor_id                   timestamp  value   time
# 0        2349697       6632  2020-03-24 20:51:13.574159    0.0  75073
# 6        2349703       6632  2020-03-24 20:51:14.822827    0.0  75074
# 11       2349708       6632  2020-03-24 20:51:16.127826    0.0  75076
# 17       2349714       6632  2020-03-24 20:51:17.439496    0.0  75077
# 23       2349720       6632  2020-03-24 20:51:18.745083    0.0  75078
# ...          ...        ...                         ...    ...    ...
# 499972   6569960       6632  2020-04-17 12:51:21.843234    0.0  46281
# 499978   6569966       6632  2020-04-17 12:51:23.141396    0.0  46283
# 499984   6569972       6632  2020-04-17 12:51:24.451749    0.0  46284
# 499990   6569978       6632  2020-04-17 12:51:25.761062    0.0  46285
# 499997   6569985       6632  2020-04-17 12:51:27.085337    0.0  46287
#
# [584362 rows x 5 columns]

# %% [markdown]
# ### inspect 6633 sandwichmaker

# %%
df = util.line_plot_multi(multi_float, 6633, "sandwichmaker", 550000, [0,2200])

# %%
df = util.hist_plot_multi(multi_float, 6633, "sandwichmaker", [0,300])

# %% [markdown]
# ## inspect 6635 kettle

# %%
df = util.line_plot_multi(multi_float, 6635, "kettle", 550000, [0,600])

# %%
df = util.hist_plot_multi(multi_float, 6635, "kettle", [0,100000])

# %% [markdown]
# ## inspect 6896 microwave

# %%
df = util.line_plot_multi(multi_float, 6896, "microwave", 55000, [0,1500])

# %%
df = util.hist_plot_multi(multi_float, 6896, "microwave", [0,400])

# %% [markdown]
# # Multi_sensor_Int

# %% [markdown]
# ## inspect 5895 bathroom

# %%
multi_int
# Out:
#          value_id  sensor_id                   timestamp  value   time
# 0        61071473       5891  2020-03-24 16:50:55.682281      0  60655
# 1        61071474       5895  2020-03-24 16:50:55.754753      0  60655
# 2        61071475       5894  2020-03-24 16:50:55.766631      0  60655
# 3        61071476       6686  2020-03-24 16:50:55.970343      0  60655
# 4        61071477       5889  2020-03-24 16:50:56.015072    261  60656
# ...           ...        ...                         ...    ...    ...
# 499996  101996494       5887  2020-04-02 14:55:22.168633    202  53722
# 499997  101996495       6686  2020-04-02 14:55:22.179351      0  53722
# 499998  101996496       5893  2020-04-02 14:55:22.197759      0  53722
# 499999  101996497       5889  2020-04-02 14:55:22.263626    321  53722
# 500000  101996498       5896  2020-04-02 14:55:22.394058    608  53722
#
# [9000018 rows x 5 columns]

# %%
df = util.line_plot_multi(multi_int, 5895, "bathroom motion", 5000, [0,2])

# %%
df = util.hist_plot_multi(multi_int, 5895, "bathroom motion", [0,2000000])

# %% [markdown]
# ## inspect 7125 bathroom light

# %%
## This sensor was not in the first files

# %%
df = util.line_plot_multi(multi_int, 7125, "bathroom light", 91000, [0,2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-1b65eb8e1365> in <module>
# ----> 1 df = util.line_plot_multi(multi_int, 7125, "bathroom light", 91000, [0,2])
#
# C:\Universitaet\WiSe2021\WiSe2021\AHMIAS\test\SmartHomeAssistant_HMISeminar\util.py in line_plot_multi(df, sensor, name, num_rows, ylim)
#     147     y = df_use.iloc[0:num_rows, 3]
#     148
# --> 149     ax.plot(x, y)
#     150
#     151     ax.set_title("first " + str(num_rows) + " of " + name)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ...

# %%
multi_int[multi_int['sensor_id'] == 7125]
# Out:
# Empty DataFrame
# Columns: [value_id, sensor_id, timestamp, value, time]
# Index: []

# %% [markdown]
# ## inspect 5896 bed pressure

# %%
df = util.line_plot_multi(multi_int, 5896, "bed pressure", 91000, [600,680])

# %%
df = util.hist_plot_multi(multi_int, 5896, "bed pressure", [0,50000])

# %% [markdown]
# ## inspect 6253 kitchen fridge

# %%
df = util.line_plot_multi(multi_int, 6253, "kitchen fridge", 700000, [0,1.2])

# %%
df = util.hist_plot_multi(multi_int, 6253, "kitchen fridge", [0,2000000])

# %%
df['value'].value_counts()
# Out:
# 0    1817070
# 1       5320
# Name: value, dtype: int64

# %% [markdown]
# ## inspect 5887 stove light

# %%
df = util.line_plot_multi(multi_int, 5887, "stove light", 700000, [0,1200])

# %%
df = util.hist_plot_multi(multi_int, 5887, "stove light", [0,30000])

# %% [markdown]
# ## inspect 5888 entrance door contact

# %%
df = util.line_plot_multi(multi_int, 5888, "entrance door", 360000, [0,1.1])

# %%
df = util.hist_plot_multi(multi_int, 5888, "entrance door", [0,370000])

# %% [markdown]
# ## inspect 5889 couch pressure

# %%
df = util.line_plot_multi(multi_int, 5889, "couch pressure", 550000, [200,450])

# %%
df = util.hist_plot_multi(multi_int, 5889, "couch pressure", [0,100000])

# %% [markdown]
# ## inspect 5893 kitchen motion

# %%
df = util.line_plot_multi(multi_int, 5893, "kitchen motion", 700000, [0,1.5])

# %%
df = util.hist_plot_multi(multi_int, 5893, "kitchen motion", [0,700000])
